# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import os, random
import sys
from astropy.table import Table
import pandas as pd
import astropy

from data import KMTData
from data import OGLEData


random.seed(42)

# %%
event_dir = '/home/fran/data/OGLE_ews/2017/blg-1087'

data1 = OGLEData('/home/fran/data/OGLE_ews/2017/blg-1087')
data2 = OGLEData('/home/fran/data/OGLE_ews/2017/blg-1089')
data_sum = data1 + data2

# %%
kmt_dir = '/home/fran/data/KMT/kmtnet/2017/2017/KB170002'

data = KMTData(kmt_dir)

# %%
fig, ax = plt.subplots(figsize=(15,5))

data.plot(ax)
