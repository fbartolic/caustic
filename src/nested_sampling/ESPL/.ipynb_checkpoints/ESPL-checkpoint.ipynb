# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import pandas as pd

mpl.rc('font',**{'family':'serif','serif':['Palatino']})
mpl.rc('text', usetex=True)
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 20

# %matplotlib inline

# Better looking figures
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # ESPL with Gaussian likelihood

# %%
# !cat gaussian_model/OPTIONS
# Out:
# #File containing parameters for DNest4
# # Put comments at the top, or at the end of the line.
# 2 # Number of particles per thread
# 10000   # new level interval
# 1   # save interval
# 100     # threadSteps - how many steps each thread should do independently before communication
# 0      # maximum number of levels
# 10      # Backtracking scale length (lambda in the paper)
# 100     # Strength of effect to force histogram to equal push (beta in the paper)
# 20000	# Maximum number of saves (0 = infinite)

# %%
event = '2017/blg-0401' # '2017/0717'

data = pd.read_csv('../../microlensing_data/OGLE/' + event + '/phot.dat', 
                   names=['HJD', 'I_flux', 'I_flux_err', 'seeing_est', 'sky_level'],
                   delim_whitespace=True)

mag_to_flux = lambda m: 10**(-m/2.5)
magerr_to_fluxerr = lambda m, sigm: sigm*mag_to_flux(m)

data['HJD'] -= 2450000
data['I_flux_err'] = magerr_to_fluxerr(data['I_flux'].values, data['I_flux_err'].values)
data['I_flux'] = mag_to_flux(data['I_flux'].values)

# Normalize flux units
data['I_flux'] = (data['I_flux'] - data['I_flux'].min())/(data['I_flux'].max() - data['I_flux'].min())
data['I_flux_err'] = data['I_flux_err']/(data['I_flux'].max() - data['I_flux'].min())

# Save to .txt file, to be read by DNest4
np.savetxt('lightcurve.txt', data.values[:, :-2])

# %%
# Compile DNest4
# !cd gaussian_model/
# !make clean
# !make
# Out:
# make: *** No rule to make target 'clean'. Stop.
# make: *** No targets specified and no makefile found. Stop.

# %%
# Run DNest4 model on 4 threads
# !./main -t 4
# Out:
# # Using 4 threads.
# # Target compression factor between levels = 2.7182818284590451
# # Seeding random number generators. First seed = 1519395505.
# # Generating 8 particles from the prior...done.
# # Saving particle to disk. N = 1.
# # Saving particle to disk. N = 2.
# # Saving particle to disk. N = 3.
# # Saving particle to disk. N = 4.
# # Saving particle to disk. N = 5.
# # Saving particle to disk. N = 6.
# # Saving particle to disk. N = 7.
# # Saving particle to disk. N = 8.
# # Saving particle to disk. N = 9.
# # Saving particle to disk. N = 10.
# # Saving particle to disk. N = 11.
# # Saving particle to disk. N = 12.
# # Saving particle to disk. N = 13.
# # Saving particle to disk. N = 14.
# # Saving particle to disk. N = 15.
# # Saving particle to disk. N = 16.
# # Saving particle to disk. N = 17.
# # Saving particle to disk. N = 18.
# # Saving particle to disk. N = 19.
# # Saving particle to disk. N = 20.
# # Saving particle to disk. N = 21.
# # Saving particle to disk. N = 22.
# # Saving particle to disk. N = 23.
# # Saving particle to disk. N = 24.
# # Creating level 1 with log likelihood = -35823380.1312.
# # Saving particle to disk. N = 25.
# # Saving particle to disk. N = 26.
# # Saving particle to disk. N = 27.
# # Saving particle to disk. N = 28.
# # Saving particle to disk. N = 29.
# # Saving particle to disk. N = 30.
# # Saving particle to disk. N = 31.
# # Saving particle to disk. N = 32.
# # Saving particle to disk. N = 33.
# # Saving particle to disk. N = 34.
# # Saving particle to disk. N = 35.
# # Saving particle to disk. N = 36.
# # Saving particle to disk. N = 37.
# # Saving particle to disk. N = 38.
# # Saving particle to disk. N = 39.
# # Saving particle to disk. N = 40.
# # Saving particle to disk. N = 41.
# # Saving particle to disk. N = 42.
# # Saving particle to disk. N = 43.
# # Saving particle to disk. N = 44.
# # Saving particle to disk. N = 45.
# # Saving particle to disk. N = 46.
# # Saving particle to disk. N = 47.
# # Creating level 2 with log likelihood = -6889682.30984.
# # Saving particle to disk. N = 48.
# # Saving particle to disk. N = 49.
# # Saving particle to disk. N = 50.
# # Saving particle to disk. N = 51.
# # Saving particle to disk. N = 52.
# # Saving particle to disk. N = 53.
# # Saving particle to disk. N = 54.
# # Saving particle to disk. N = 55.
# # Saving particle to disk. N = 56.
# # Saving particle to disk. N = 57.
# # Saving particle to disk. N = 58.
# # Saving particle to disk. N = 59.
# # Saving particle to disk. N = 60.
# # Saving particle to disk. N = 61.
# # Saving particle to disk. N = 62.
# # Saving particle to disk. N = 63.
# # Saving particle to disk. N = 64.
# # Saving particle to disk. N = 65.
# # Saving particle to disk. N = 66.
# # Saving particle to disk. N = 67.
# # Saving particle to disk. N = 68.
# # Saving particle to disk. N = 69.
# # Saving particle to disk. N = 70.
# # Saving particle to disk. N = 71.
# # Saving particle to disk. N = 72.
# # Saving particle to disk. N = 73.
# # Saving particle to disk. N = 74.
# # Saving particle to disk. N = 75.
# # Saving particle to disk. N = 76.
# # Creating level 3 with log likelihood = -1473444.47993.
# # Saving particle to disk. N = 77.
# # Saving particle to disk. N = 78.
# # Saving particle to disk. N = 79.
# # Saving particle to disk. N = 80.
# # Saving particle to disk. N = 81.
# # Saving particle to disk. N = 82.
# # Saving particle to disk. N = 83.
# # Saving particle to disk. N = 84.
# # Saving particle to disk. N = 85.
# # Saving particle to disk. N = 86.
# # Saving particle to disk. N = 87.
# # Saving particle to disk. N = 88.
# # Saving particle to disk. N = 89.
# # Saving particle to disk. N = 90.
# # Saving particle to disk. N = 91.
# # Saving particle to disk. N = 92.
# # Saving particle to disk. N = 93.
# # Saving particle to disk. N = 94.
# # Saving particle to disk. N = 95.
# # Saving particle to disk. N = 96.
# # Saving particle to disk. N = 97.
# # Saving particle to disk. N = 98.
# # Saving particle to disk. N = 99.
# # Saving particle to disk. N = 100.
# # Saving particle to disk. N = 101.
# # Saving particle to disk. N = 102.
# # Saving particle to disk. N = 103.
# # Saving particle to disk. N = 104.
# # Saving particle to disk. N = 105.
# # Saving particle to disk. N = 106.
# # Saving particle to disk. N = 107.
# # Saving particle to disk. N = 108.
# # Saving particle to disk. N = 109.
# # Saving particle to disk. N = 110.
# # Saving particle to disk. N = 111.
# # Saving particle to disk. N = 112.
# # Creating level 4 with log likelihood = -323825.933605.
# # Saving particle to disk. N = 113.
# # Saving particle to disk. N = 114.
# # Saving particle to disk. N = 115.
# # Saving particle to disk. N = 116.
# # Saving particle to disk. N = 117.
# # Saving particle to disk. N = 118.
# # Saving particle to disk. N = 119.
# # Saving particle to disk. N = 120.
# # Saving particle to disk. N = 121.
# # Saving particle to disk. N = 122.
# # Saving particle to disk. N = 123.
# # Saving particle to disk. N = 124.
# # Saving particle to disk. N = 125.
# # Saving particle to disk. N = 126.
# # Saving particle to disk. N = 127.
# # Saving particle to disk. N = 128.
# # Saving particle to disk. N = 129.
# # Saving particle to disk. N = 130.
# # Saving particle to disk. N = 131.
# # Saving particle to disk. N = 132.
# # Saving particle to disk. N = 133.
# # Saving particle to disk. N = 134.
# # Saving particle to disk. N = 135.
# # Saving particle to disk. N = 136.
# # Saving particle to disk. N = 137.
# # Saving particle to disk. N = 138.
# # Saving particle to disk. N = 139.
# # Saving particle to disk. N = 140.
# # Saving particle to disk. N = 141.
# # Saving particle to disk. N = 142.
# # Saving particle to disk. N = 143.
# # Saving particle to disk. N = 144.
# # Saving particle to disk. N = 145.
# # Saving particle to disk. N = 146.
# # Saving particle to disk. N = 147.
# # Saving particle to disk. N = 148.
# # Saving particle to disk. N = 149.
# # Saving particle to disk. N = 150.
# # Saving particle to disk. N = 151.
# # Saving particle to disk. N = 152.
# # Creating level 5 with log likelihood = -102584.519408.
# # Saving particle to disk. N = 153.
# # Saving particle to disk. N = 154.
# # Saving particle to disk. N = 155.
# # Saving particle to disk. N = 156.
# # Saving particle to disk. N = 157.
# # Saving particle to disk. N = 158.
# # Saving particle to disk. N = 159.
# # Saving particle to disk. N = 160.
# # Saving particle to disk. N = 161.
# # Saving particle to disk. N = 162.
# # Saving particle to disk. N = 163.
# # Saving particle to disk. N = 164.
# # Saving particle to disk. N = 165.
# # Saving particle to disk. N = 166.
# # Saving particle to disk. N = 167.
# # Saving particle to disk. N = 168.
# # Saving particle to disk. N = 169.
# # Saving particle to disk. N = 170.
# # Saving particle to disk. N = 171.
# # Saving particle to disk. N = 172.
# # Saving particle to disk. N = 173.
# # Saving particle to disk. N = 174.
# # Saving particle to disk. N = 175.
# # Saving particle to disk. N = 176.
# # Saving particle to disk. N = 177.
# # Saving particle to disk. N = 178.
# # Saving particle to disk. N = 179.
# # Saving particle to disk. N = 180.
# # Saving particle to disk. N = 181.
# # Saving particle to disk. N = 182.
# # Saving particle to disk. N = 183.
# # Saving particle to disk. N = 184.
# # Saving particle to disk. N = 185.
# # Saving particle to disk. N = 186.
# # Saving particle to disk. N = 187.
# # Saving particle to disk. N = 188.
# # Saving particle to disk. N = 189.
# # Saving particle to disk. N = 190.
# # Saving particle to disk. N = 191.
# # Saving particle to disk. N = 192.
# # Saving particle to disk. N = 193.
# # Saving particle to disk. N = 194.
# # Saving particle to disk. N = 195.
# # Saving particle to disk. N = 196.
# # Saving particle to disk. N = 197.
# # Saving particle to disk. N = 198.
# # Creating level 6 with log likelihood = -36067.833047.
# # Saving particle to disk. N = 199.
# # Saving particle to disk. N = 200.
# # Saving particle to disk. N = 201.
# # Saving particle to disk. N = 202.
# # Saving particle to disk. N = 203.
# # Saving particle to disk. N = 204.
# # Saving particle to disk. N = 205.
# # Saving particle to disk. N = 206.
# # Saving particle to disk. N = 207.
# # Saving particle to disk. N = 208.
# # Saving particle to disk. N = 209.
# # Saving particle to disk. N = 210.
# # Saving particle to disk. N = 211.
# # Saving particle to disk. N = 212.
# # Saving particle to disk. N = 213.
# # Saving particle to disk. N = 214.
# # Saving particle to disk. N = 215.
# # Saving particle to disk. N = 216.
# # Saving particle to disk. N = 217.
# # Saving particle to disk. N = 218.
# # Saving particle to disk. N = 219.
# # Saving particle to disk. N = 220.
# # Saving particle to disk. N = 221.
# # Saving particle to disk. N = 222.
# # Saving particle to disk. N = 223.
# # Saving particle to disk. N = 224.
# # Saving particle to disk. N = 225.
# # Saving particle to disk. N = 226.
# # Saving particle to disk. N = 227.
# # Saving particle to disk. N = 228.
# # Saving particle to disk. N = 229.
# # Saving particle to disk. N = 230.
# # Saving particle to disk. N = 231.
# # Saving particle to disk. N = 232.
# # Saving particle to disk. N = 233.
# # Saving particle to disk. N = 234.
# # Saving particle to disk. N = 235.
# # Saving particle to disk. N = 236.
# # Saving particle to disk. N = 237.
# # Saving particle to disk. N = 238.
# # Saving particle to disk. N = 239.
# # Saving particle to disk. N = 240.
# # Saving particle to disk. N = 241.
# # Saving particle to disk. N = 242.
# # Saving particle to disk. N = 243.
# # Saving particle to disk. N = 244.
# # Saving particle to disk. N = 245.
# # Saving particle to disk. N = 246.
# # Saving particle to disk. N = 247.
# # Saving particle to disk. N = 248.
# # Saving particle to disk. N = 249.
# # Saving particle to disk. N = 250.
# # Creating level 7 with log likelihood = -14508.1080305.
# # Saving particle to disk. N = 251.
# # Saving particle to disk. N = 252.
# # Saving particle to disk. N = 253.
# # Saving particle to disk. N = 254.
# # Saving particle to disk. N = 255.
# # Saving particle to disk. N = 256.
# # Saving particle to disk. N = 257.
# # Saving particle to disk. N = 258.
# # Saving particle to disk. N = 259.
# # Saving particle to disk. N = 260.
# # Saving particle to disk. N = 261.
# # Saving particle to disk. N = 262.
# # Saving particle to disk. N = 263.
# # Saving particle to disk. N = 264.
# # Saving particle to disk. N = 265.
# # Saving particle to disk. N = 266.
# # Saving particle to disk. N = 267.
# # Saving particle to disk. N = 268.
# # Saving particle to disk. N = 269.
# # Saving particle to disk. N = 270.
# # Saving particle to disk. N = 271.
# # Saving particle to disk. N = 272.
# # Saving particle to disk. N = 273.
# # Saving particle to disk. N = 274.
# # Saving particle to disk. N = 275.
# # Saving particle to disk. N = 276.
# # Saving particle to disk. N = 277.
# # Saving particle to disk. N = 278.
# # Saving particle to disk. N = 279.
# # Saving particle to disk. N = 280.
# # Saving particle to disk. N = 281.
# # Saving particle to disk. N = 282.
# # Saving particle to disk. N = 283.
# # Saving particle to disk. N = 284.
# # Saving particle to disk. N = 285.
# # Saving particle to disk. N = 286.
# # Saving particle to disk. N = 287.
# # Saving particle to disk. N = 288.
# # Saving particle to disk. N = 289.
# # Saving particle to disk. N = 290.
# # Saving particle to disk. N = 291.
# # Saving particle to disk. N = 292.
# # Saving particle to disk. N = 293.
# # Saving particle to disk. N = 294.
# # Saving particle to disk. N = 295.
# # Saving particle to disk. N = 296.
# # Saving particle to disk. N = 297.
# # Saving particle to disk. N = 298.
# # Saving particle to disk. N = 299.
# # Saving particle to disk. N = 300.
# # Saving particle to disk. N = 301.
# # Saving particle to disk. N = 302.
# # Saving particle to disk. N = 303.
# # Saving particle to disk. N = 304.
# # Saving particle to disk. N = 305.
# # Saving particle to disk. N = 306.
# # Saving particle to disk. N = 307.
# # Saving particle to disk. N = 308.
# # Saving particle to disk. N = 309.
# # Saving particle to disk. N = 310.
# # Saving particle to disk. N = 311.
# # Saving particle to disk. N = 312.
# # Saving particle to disk. N = 313.
# # Saving particle to disk. N = 314.
# # Saving particle to disk. N = 315.
# # Saving particle to disk. N = 316.
# # Saving particle to disk. N = 317.
# # Saving particle to disk. N = 318.
# # Saving particle to disk. N = 319.
# # Creating level 8 with log likelihood = -7927.4296984.
# # Saving particle to disk. N = 320.
# # Saving particle to disk. N = 321.
# # Saving particle to disk. N = 322.
# # Saving particle to disk. N = 323.
# # Saving particle to disk. N = 324.
# # Saving particle to disk. N = 325.
# # Saving particle to disk. N = 326.
# # Saving particle to disk. N = 327.
# # Saving particle to disk. N = 328.
# # Saving particle to disk. N = 329.
# # Saving particle to disk. N = 330.
# # Saving particle to disk. N = 331.
# # Saving particle to disk. N = 332.
# # Saving particle to disk. N = 333.
# # Saving particle to disk. N = 334.
# # Saving particle to disk. N = 335.
# # Saving particle to disk. N = 336.
# # Saving particle to disk. N = 337.
# # Saving particle to disk. N = 338.
# # Saving particle to disk. N = 339.
# # Saving particle to disk. N = 340.
# # Saving particle to disk. N = 341.
# # Saving particle to disk. N = 342.
# # Saving particle to disk. N = 343.
# # Saving particle to disk. N = 344.
# # Saving particle to disk. N = 345.
# # Saving particle to disk. N = 346.
# # Saving particle to disk. N = 347.
# # Saving particle to disk. N = 348.
# # Saving particle to disk. N = 349.
# # Saving particle to disk. N = 350.
# # Saving particle to disk. N = 351.
# # Saving particle to disk. N = 352.
# # Saving particle to disk. N = 353.
# # Saving particle to disk. N = 354.
# # Saving particle to disk. N = 355.
# # Saving particle to disk. N = 356.
# # Saving particle to disk. N = 357.
# # Saving particle to disk. N = 358.
# # Saving particle to disk. N = 359.
# # Saving particle to disk. N = 360.
# # Saving particle to disk. N = 361.
# # Saving particle to disk. N = 362.
# # Saving particle to disk. N = 363.
# # Saving particle to disk. N = 364.
# # Saving particle to disk. N = 365.
# # Saving particle to disk. N = 366.
# # Saving particle to disk. N = 367.
# # Saving particle to disk. N = 368.
# # Saving particle to disk. N = 369.
# # Saving particle to disk. N = 370.
# # Saving particle to disk. N = 371.
# # Saving particle to disk. N = 372.
# # Saving particle to disk. N = 373.
# # Saving particle to disk. N = 374.
# # Saving particle to disk. N = 375.
# # Saving particle to disk. N = 376.
# # Saving particle to disk. N = 377.
# # Saving particle to disk. N = 378.
# # Saving particle to disk. N = 379.
# # Saving particle to disk. N = 380.
# # Saving particle to disk. N = 381.
# # Saving particle to disk. N = 382.
# # Saving particle to disk. N = 383.
# # Saving particle to disk. N = 384.
# # Creating level 9 with log likelihood = -5918.35016183.
# # Saving particle to disk. N = 385.
# # Saving particle to disk. N = 386.
# # Saving particle to disk. N = 387.
# # Saving particle to disk. N = 388.
# # Saving particle to disk. N = 389.
# # Saving particle to disk. N = 390.
# # Saving particle to disk. N = 391.
# # Saving particle to disk. N = 392.
# # Saving particle to disk. N = 393.
# # Saving particle to disk. N = 394.
# # Saving particle to disk. N = 395.
# # Saving particle to disk. N = 396.
# # Saving particle to disk. N = 397.
# # Saving particle to disk. N = 398.
# # Saving particle to disk. N = 399.
# # Saving particle to disk. N = 400.
# # Saving particle to disk. N = 401.
# # Saving particle to disk. N = 402.
# # Saving particle to disk. N = 403.
# # Saving particle to disk. N = 404.
# # Saving particle to disk. N = 405.
# # Saving particle to disk. N = 406.
# # Saving particle to disk. N = 407.
# # Saving particle to disk. N = 408.
# # Saving particle to disk. N = 409.
# # Saving particle to disk. N = 410.
# # Saving particle to disk. N = 411.
# # Saving particle to disk. N = 412.
# # Saving particle to disk. N = 413.
# # Saving particle to disk. N = 414.
# # Saving particle to disk. N = 415.
# # Saving particle to disk. N = 416.
# # Saving particle to disk. N = 417.
# # Saving particle to disk. N = 418.
# # Saving particle to disk. N = 419.
# # Saving particle to disk. N = 420.
# # Saving particle to disk. N = 421.
# # Saving particle to disk. N = 422.
# # Saving particle to disk. N = 423.
# # Saving particle to disk. N = 424.
# # Saving particle to disk. N = 425.
# # Saving particle to disk. N = 426.
# # Saving particle to disk. N = 427.
# # Saving particle to disk. N = 428.
# # Saving particle to disk. N = 429.
# # Saving particle to disk. N = 430.
# # Saving particle to disk. N = 431.
# # Saving particle to disk. N = 432.
# # Saving particle to disk. N = 433.
# # Saving particle to disk. N = 434.
# # Saving particle to disk. N = 435.
# # Saving particle to disk. N = 436.
# # Saving particle to disk. N = 437.
# # Saving particle to disk. N = 438.
# # Saving particle to disk. N = 439.
# # Saving particle to disk. N = 440.
# # Saving particle to disk. N = 441.
# # Saving particle to disk. N = 442.
# # Saving particle to disk. N = 443.
# # Saving particle to disk. N = 444.
# # Saving particle to disk. N = 445.
# # Saving particle to disk. N = 446.
# # Saving particle to disk. N = 447.
# # Saving particle to disk. N = 448.
# # Saving particle to disk. N = 449.
# # Saving particle to disk. N = 450.
# # Saving particle to disk. N = 451.
# # Saving particle to disk. N = 452.
# # Saving particle to disk. N = 453.
# # Saving particle to disk. N = 454.
# # Saving particle to disk. N = 455.
# # Saving particle to disk. N = 456.
# # Saving particle to disk. N = 457.
# # Creating level 10 with log likelihood = -5382.2529062.
# # Saving particle to disk. N = 458.
# # Saving particle to disk. N = 459.
# # Saving particle to disk. N = 460.
# # Saving particle to disk. N = 461.
# # Saving particle to disk. N = 462.
# # Saving particle to disk. N = 463.
# # Saving particle to disk. N = 464.
# # Saving particle to disk. N = 465.
# # Saving particle to disk. N = 466.
# # Saving particle to disk. N = 467.
# # Saving particle to disk. N = 468.
# # Saving particle to disk. N = 469.
# # Saving particle to disk. N = 470.
# # Saving particle to disk. N = 471.
# # Saving particle to disk. N = 472.
# # Saving particle to disk. N = 473.
# # Saving particle to disk. N = 474.
# # Saving particle to disk. N = 475.
# # Saving particle to disk. N = 476.
# # Saving particle to disk. N = 477.
# # Saving particle to disk. N = 478.
# # Saving particle to disk. N = 479.
# # Saving particle to disk. N = 480.
# # Saving particle to disk. N = 481.
# # Saving particle to disk. N = 482.
# # Saving particle to disk. N = 483.
# # Saving particle to disk. N = 484.
# # Saving particle to disk. N = 485.
# # Saving particle to disk. N = 486.
# # Saving particle to disk. N = 487.
# # Saving particle to disk. N = 488.
# # Saving particle to disk. N = 489.
# # Saving particle to disk. N = 490.
# # Saving particle to disk. N = 491.
# # Saving particle to disk. N = 492.
# # Saving particle to disk. N = 493.
# # Saving particle to disk. N = 494.
# # Saving particle to disk. N = 495.
# # Saving particle to disk. N = 496.
# # Saving particle to disk. N = 497.
# # Saving particle to disk. N = 498.
# # Saving particle to disk. N = 499.
# # Saving particle to disk. N = 500.
# # Saving particle to disk. N = 501.
# # Saving particle to disk. N = 502.
# # Saving particle to disk. N = 503.
# # Saving particle to disk. N = 504.
# # Saving particle to disk. N = 505.
# # Saving particle to disk. N = 506.
# # Saving particle to disk. N = 507.
# # Saving particle to disk. N = 508.
# # Saving particle to disk. N = 509.
# # Saving particle to disk. N = 510.
# # Saving particle to disk. N = 511.
# # Saving particle to disk. N = 512.
# # Saving particle to disk. N = 513.
# # Saving particle to disk. N = 514.
# # Saving particle to disk. N = 515.
# # Saving particle to disk. N = 516.
# # Saving particle to disk. N = 517.
# # Saving particle to disk. N = 518.
# # Saving particle to disk. N = 519.
# # Saving particle to disk. N = 520.
# # Saving particle to disk. N = 521.
# # Saving particle to disk. N = 522.
# # Saving particle to disk. N = 523.
# # Saving particle to disk. N = 524.
# # Saving particle to disk. N = 525.
# # Saving particle to disk. N = 526.
# # Saving particle to disk. N = 527.
# # Saving particle to disk. N = 528.
# # Saving particle to disk. N = 529.
# # Saving particle to disk. N = 530.
# # Saving particle to disk. N = 531.
# # Creating level 11 with log likelihood = -5188.00202451.
# # Saving particle to disk. N = 532.
# # Saving particle to disk. N = 533.
# # Saving particle to disk. N = 534.
# # Saving particle to disk. N = 535.
# # Saving particle to disk. N = 536.
# # Saving particle to disk. N = 537.
# # Saving particle to disk. N = 538.
# # Saving particle to disk. N = 539.
# # Saving particle to disk. N = 540.
# # Saving particle to disk. N = 541.
# # Saving particle to disk. N = 542.
# # Saving particle to disk. N = 543.
# # Saving particle to disk. N = 544.
# # Saving particle to disk. N = 545.
# # Saving particle to disk. N = 546.
# # Saving particle to disk. N = 547.
# # Saving particle to disk. N = 548.
# # Saving particle to disk. N = 549.
# # Saving particle to disk. N = 550.
# # Saving particle to disk. N = 551.
# # Saving particle to disk. N = 552.
# # Saving particle to disk. N = 553.
# # Saving particle to disk. N = 554.
# # Saving particle to disk. N = 555.
# # Saving particle to disk. N = 556.
# # Saving particle to disk. N = 557.
# # Saving particle to disk. N = 558.
# # Saving particle to disk. N = 559.
# # Saving particle to disk. N = 560.
# # Saving particle to disk. N = 561.
# # Saving particle to disk. N = 562.
# # Saving particle to disk. N = 563.
# # Saving particle to disk. N = 564.
# # Saving particle to disk. N = 565.
# # Saving particle to disk. N = 566.
# # Saving particle to disk. N = 567.
# # Saving particle to disk. N = 568.
# # Saving particle to disk. N = 569.
# # Saving particle to disk. N = 570.
# # Saving particle to disk. N = 571.
# # Saving particle to disk. N = 572.
# # Saving particle to disk. N = 573.
# # Saving particle to disk. N = 574.
# # Saving particle to disk. N = 575.
# # Saving particle to disk. N = 576.
# # Saving particle to disk. N = 577.
# # Saving particle to disk. N = 578.
# # Saving particle to disk. N = 579.
# # Saving particle to disk. N = 580.
# # Saving particle to disk. N = 581.
# # Saving particle to disk. N = 582.
# # Saving particle to disk. N = 583.
# # Saving particle to disk. N = 584.
# # Saving particle to disk. N = 585.
# # Saving particle to disk. N = 586.
# # Saving particle to disk. N = 587.
# # Saving particle to disk. N = 588.
# # Saving particle to disk. N = 589.
# # Saving particle to disk. N = 590.
# # Saving particle to disk. N = 591.
# # Saving particle to disk. N = 592.
# # Saving particle to disk. N = 593.
# # Saving particle to disk. N = 594.
# # Saving particle to disk. N = 595.
# # Saving particle to disk. N = 596.
# # Saving particle to disk. N = 597.
# # Saving particle to disk. N = 598.
# # Saving particle to disk. N = 599.
# # Saving particle to disk. N = 600.
# # Saving particle to disk. N = 601.
# # Saving particle to disk. N = 602.
# # Saving particle to disk. N = 603.
# # Saving particle to disk. N = 604.
# # Creating level 12 with log likelihood = -4790.96814433.
# # Saving particle to disk. N = 605.
# # Saving particle to disk. N = 606.
# # Saving particle to disk. N = 607.
# # Saving particle to disk. N = 608.
# # Saving particle to disk. N = 609.
# # Saving particle to disk. N = 610.
# # Saving particle to disk. N = 611.
# # Saving particle to disk. N = 612.
# # Saving particle to disk. N = 613.
# # Saving particle to disk. N = 614.
# # Saving particle to disk. N = 615.
# # Saving particle to disk. N = 616.
# # Saving particle to disk. N = 617.
# # Saving particle to disk. N = 618.
# # Saving particle to disk. N = 619.
# # Saving particle to disk. N = 620.
# # Saving particle to disk. N = 621.
# # Saving particle to disk. N = 622.
# # Saving particle to disk. N = 623.
# # Saving particle to disk. N = 624.
# # Saving particle to disk. N = 625.
# # Saving particle to disk. N = 626.
# # Saving particle to disk. N = 627.
# # Saving particle to disk. N = 628.
# # Saving particle to disk. N = 629.
# # Saving particle to disk. N = 630.
# # Saving particle to disk. N = 631.
# # Saving particle to disk. N = 632.
# # Saving particle to disk. N = 633.
# # Saving particle to disk. N = 634.
# # Saving particle to disk. N = 635.
# # Saving particle to disk. N = 636.
# # Saving particle to disk. N = 637.
# # Saving particle to disk. N = 638.
# # Saving particle to disk. N = 639.
# # Saving particle to disk. N = 640.
# # Saving particle to disk. N = 641.
# # Saving particle to disk. N = 642.
# # Saving particle to disk. N = 643.
# # Saving particle to disk. N = 644.
# # Saving particle to disk. N = 645.
# # Saving particle to disk. N = 646.
# # Saving particle to disk. N = 647.
# # Saving particle to disk. N = 648.
# # Saving particle to disk. N = 649.
# # Saving particle to disk. N = 650.
# # Saving particle to disk. N = 651.
# # Saving particle to disk. N = 652.
# # Saving particle to disk. N = 653.
# # Saving particle to disk. N = 654.
# # Saving particle to disk. N = 655.
# # Saving particle to disk. N = 656.
# # Saving particle to disk. N = 657.
# # Saving particle to disk. N = 658.
# # Saving particle to disk. N = 659.
# # Saving particle to disk. N = 660.
# # Saving particle to disk. N = 661.
# # Saving particle to disk. N = 662.
# # Saving particle to disk. N = 663.
# # Saving particle to disk. N = 664.
# # Saving particle to disk. N = 665.
# # Saving particle to disk. N = 666.
# # Saving particle to disk. N = 667.
# # Saving particle to disk. N = 668.
# # Saving particle to disk. N = 669.
# # Saving particle to disk. N = 670.
# # Saving particle to disk. N = 671.
# # Creating level 13 with log likelihood = -4262.49947758.
# # Saving particle to disk. N = 672.
# # Saving particle to disk. N = 673.
# # Saving particle to disk. N = 674.
# # Saving particle to disk. N = 675.
# # Saving particle to disk. N = 676.
# # Saving particle to disk. N = 677.
# # Saving particle to disk. N = 678.
# # Saving particle to disk. N = 679.
# # Saving particle to disk. N = 680.
# # Saving particle to disk. N = 681.
# # Saving particle to disk. N = 682.
# # Saving particle to disk. N = 683.
# # Saving particle to disk. N = 684.
# # Saving particle to disk. N = 685.
# # Saving particle to disk. N = 686.
# # Saving particle to disk. N = 687.
# # Saving particle to disk. N = 688.
# # Saving particle to disk. N = 689.
# # Saving particle to disk. N = 690.
# # Saving particle to disk. N = 691.
# # Saving particle to disk. N = 692.
# # Saving particle to disk. N = 693.
# # Saving particle to disk. N = 694.
# # Saving particle to disk. N = 695.
# # Saving particle to disk. N = 696.
# # Saving particle to disk. N = 697.
# # Saving particle to disk. N = 698.
# # Saving particle to disk. N = 699.
# # Saving particle to disk. N = 700.
# # Saving particle to disk. N = 701.
# # Saving particle to disk. N = 702.
# # Saving particle to disk. N = 703.
# # Saving particle to disk. N = 704.
# # Saving particle to disk. N = 705.
# # Saving particle to disk. N = 706.
# # Saving particle to disk. N = 707.
# # Saving particle to disk. N = 708.
# # Saving particle to disk. N = 709.
# # Saving particle to disk. N = 710.
# # Saving particle to disk. N = 711.
# # Saving particle to disk. N = 712.
# # Saving particle to disk. N = 713.
# # Saving particle to disk. N = 714.
# # Saving particle to disk. N = 715.
# # Saving particle to disk. N = 716.
# # Saving particle to disk. N = 717.
# # Saving particle to disk. N = 718.
# # Saving particle to disk. N = 719.
# # Saving particle to disk. N = 720.
# # Saving particle to disk. N = 721.
# # Saving particle to disk. N = 722.
# # Saving particle to disk. N = 723.
# # Saving particle to disk. N = 724.
# # Saving particle to disk. N = 725.
# # Saving particle to disk. N = 726.
# # Saving particle to disk. N = 727.
# # Saving particle to disk. N = 728.
# # Saving particle to disk. N = 729.
# # Saving particle to disk. N = 730.
# # Saving particle to disk. N = 731.
# # Saving particle to disk. N = 732.
# # Saving particle to disk. N = 733.
# # Saving particle to disk. N = 734.
# # Saving particle to disk. N = 735.
# # Saving particle to disk. N = 736.
# # Saving particle to disk. N = 737.
# # Saving particle to disk. N = 738.
# # Saving particle to disk. N = 739.
# # Saving particle to disk. N = 740.
# # Saving particle to disk. N = 741.
# # Saving particle to disk. N = 742.
# # Saving particle to disk. N = 743.
# # Saving particle to disk. N = 744.
# # Saving particle to disk. N = 745.
# # Saving particle to disk. N = 746.
# # Saving particle to disk. N = 747.
# # Saving particle to disk. N = 748.
# # Saving particle to disk. N = 749.
# # Saving particle to disk. N = 750.
# # Saving particle to disk. N = 751.
# # Saving particle to disk. N = 752.
# # Saving particle to disk. N = 753.
# # Saving particle to disk. N = 754.
# # Saving particle to disk. N = 755.
# # Saving particle to disk. N = 756.
# # Saving particle to disk. N = 757.
# # Saving particle to disk. N = 758.
# # Saving particle to disk. N = 759.
# # Saving particle to disk. N = 760.
# # Saving particle to disk. N = 761.
# # Saving particle to disk. N = 762.
# # Saving particle to disk. N = 763.
# # Saving particle to disk. N = 764.
# # Creating level 14 with log likelihood = -3639.24350944.
# # Saving particle to disk. N = 765.
# # Saving particle to disk. N = 766.
# # Saving particle to disk. N = 767.
# # Saving particle to disk. N = 768.
# # Saving particle to disk. N = 769.
# # Saving particle to disk. N = 770.
# # Saving particle to disk. N = 771.
# # Saving particle to disk. N = 772.
# # Saving particle to disk. N = 773.
# # Saving particle to disk. N = 774.
# # Saving particle to disk. N = 775.
# # Saving particle to disk. N = 776.
# # Saving particle to disk. N = 777.
# # Saving particle to disk. N = 778.
# # Saving particle to disk. N = 779.
# # Saving particle to disk. N = 780.
# # Saving particle to disk. N = 781.
# # Saving particle to disk. N = 782.
# # Saving particle to disk. N = 783.
# # Saving particle to disk. N = 784.
# # Saving particle to disk. N = 785.
# # Saving particle to disk. N = 786.
# # Saving particle to disk. N = 787.
# # Saving particle to disk. N = 788.
# # Saving particle to disk. N = 789.
# # Saving particle to disk. N = 790.
# # Saving particle to disk. N = 791.
# # Saving particle to disk. N = 792.
# # Saving particle to disk. N = 793.
# # Saving particle to disk. N = 794.
# # Saving particle to disk. N = 795.
# # Saving particle to disk. N = 796.
# # Saving particle to disk. N = 797.
# # Saving particle to disk. N = 798.
# # Saving particle to disk. N = 799.
# # Saving particle to disk. N = 800.
# # Saving particle to disk. N = 801.
# # Saving particle to disk. N = 802.
# # Saving particle to disk. N = 803.
# # Saving particle to disk. N = 804.
# # Saving particle to disk. N = 805.
# # Saving particle to disk. N = 806.
# # Saving particle to disk. N = 807.
# # Saving particle to disk. N = 808.
# # Saving particle to disk. N = 809.
# # Saving particle to disk. N = 810.
# # Saving particle to disk. N = 811.
# # Saving particle to disk. N = 812.
# # Saving particle to disk. N = 813.
# # Saving particle to disk. N = 814.
# # Saving particle to disk. N = 815.
# # Saving particle to disk. N = 816.
# # Saving particle to disk. N = 817.
# # Saving particle to disk. N = 818.
# # Saving particle to disk. N = 819.
# # Saving particle to disk. N = 820.
# # Saving particle to disk. N = 821.
# # Saving particle to disk. N = 822.
# # Saving particle to disk. N = 823.
# # Saving particle to disk. N = 824.
# # Saving particle to disk. N = 825.
# # Saving particle to disk. N = 826.
# # Saving particle to disk. N = 827.
# # Saving particle to disk. N = 828.
# # Saving particle to disk. N = 829.
# # Saving particle to disk. N = 830.
# # Saving particle to disk. N = 831.
# # Saving particle to disk. N = 832.
# # Saving particle to disk. N = 833.
# # Saving particle to disk. N = 834.
# # Saving particle to disk. N = 835.
# # Saving particle to disk. N = 836.
# # Saving particle to disk. N = 837.
# # Saving particle to disk. N = 838.
# # Saving particle to disk. N = 839.
# # Saving particle to disk. N = 840.
# # Saving particle to disk. N = 841.
# # Saving particle to disk. N = 842.
# # Saving particle to disk. N = 843.
# # Saving particle to disk. N = 844.
# # Saving particle to disk. N = 845.
# # Saving particle to disk. N = 846.
# # Saving particle to disk. N = 847.
# # Saving particle to disk. N = 848.
# # Saving particle to disk. N = 849.
# # Saving particle to disk. N = 850.
# # Saving particle to disk. N = 851.
# # Saving particle to disk. N = 852.
# # Saving particle to disk. N = 853.
# # Saving particle to disk. N = 854.
# # Saving particle to disk. N = 855.
# # Saving particle to disk. N = 856.
# # Saving particle to disk. N = 857.
# # Saving particle to disk. N = 858.
# # Saving particle to disk. N = 859.
# # Saving particle to disk. N = 860.
# # Saving particle to disk. N = 861.
# # Saving particle to disk. N = 862.
# # Saving particle to disk. N = 863.
# # Creating level 15 with log likelihood = -3034.50263164.
# # Saving particle to disk. N = 864.
# # Saving particle to disk. N = 865.
# # Saving particle to disk. N = 866.
# # Saving particle to disk. N = 867.
# # Saving particle to disk. N = 868.
# # Saving particle to disk. N = 869.
# # Saving particle to disk. N = 870.
# # Saving particle to disk. N = 871.
# # Saving particle to disk. N = 872.
# # Saving particle to disk. N = 873.
# # Saving particle to disk. N = 874.
# # Saving particle to disk. N = 875.
# # Saving particle to disk. N = 876.
# # Saving particle to disk. N = 877.
# # Saving particle to disk. N = 878.
# # Saving particle to disk. N = 879.
# # Saving particle to disk. N = 880.
# # Saving particle to disk. N = 881.
# # Saving particle to disk. N = 882.
# # Saving particle to disk. N = 883.
# # Saving particle to disk. N = 884.
# # Saving particle to disk. N = 885.
# # Saving particle to disk. N = 886.
# # Saving particle to disk. N = 887.
# # Saving particle to disk. N = 888.
# # Saving particle to disk. N = 889.
# # Saving particle to disk. N = 890.
# # Saving particle to disk. N = 891.
# # Saving particle to disk. N = 892.
# # Saving particle to disk. N = 893.
# # Saving particle to disk. N = 894.
# # Saving particle to disk. N = 895.
# # Saving particle to disk. N = 896.
# # Saving particle to disk. N = 897.
# # Saving particle to disk. N = 898.
# # Saving particle to disk. N = 899.
# # Saving particle to disk. N = 900.
# # Saving particle to disk. N = 901.
# # Saving particle to disk. N = 902.
# # Saving particle to disk. N = 903.
# # Saving particle to disk. N = 904.
# # Saving particle to disk. N = 905.
# # Saving particle to disk. N = 906.
# # Saving particle to disk. N = 907.
# # Saving particle to disk. N = 908.
# # Saving particle to disk. N = 909.
# # Saving particle to disk. N = 910.
# # Saving particle to disk. N = 911.
# # Saving particle to disk. N = 912.
# # Saving particle to disk. N = 913.
# # Saving particle to disk. N = 914.
# # Saving particle to disk. N = 915.
# # Saving particle to disk. N = 916.
# # Saving particle to disk. N = 917.
# # Saving particle to disk. N = 918.
# # Saving particle to disk. N = 919.
# # Saving particle to disk. N = 920.
# # Saving particle to disk. N = 921.
# # Saving particle to disk. N = 922.
# # Saving particle to disk. N = 923.
# # Saving particle to disk. N = 924.
# # Saving particle to disk. N = 925.
# # Saving particle to disk. N = 926.
# # Saving particle to disk. N = 927.
# # Saving particle to disk. N = 928.
# # Saving particle to disk. N = 929.
# # Saving particle to disk. N = 930.
# # Saving particle to disk. N = 931.
# # Saving particle to disk. N = 932.
# # Saving particle to disk. N = 933.
# # Saving particle to disk. N = 934.
# # Saving particle to disk. N = 935.
# # Creating level 16 with log likelihood = -2619.46303668.
# # Saving particle to disk. N = 936.
# # Saving particle to disk. N = 937.
# # Saving particle to disk. N = 938.
# # Saving particle to disk. N = 939.
# # Saving particle to disk. N = 940.
# # Saving particle to disk. N = 941.
# # Saving particle to disk. N = 942.
# # Saving particle to disk. N = 943.
# # Saving particle to disk. N = 944.
# # Saving particle to disk. N = 945.
# # Saving particle to disk. N = 946.
# # Saving particle to disk. N = 947.
# # Saving particle to disk. N = 948.
# # Saving particle to disk. N = 949.
# # Saving particle to disk. N = 950.
# # Saving particle to disk. N = 951.
# # Saving particle to disk. N = 952.
# # Saving particle to disk. N = 953.
# # Saving particle to disk. N = 954.
# # Saving particle to disk. N = 955.
# # Saving particle to disk. N = 956.
# # Saving particle to disk. N = 957.
# # Saving particle to disk. N = 958.
# # Saving particle to disk. N = 959.
# # Saving particle to disk. N = 960.
# # Saving particle to disk. N = 961.
# # Saving particle to disk. N = 962.
# # Saving particle to disk. N = 963.
# # Saving particle to disk. N = 964.
# # Saving particle to disk. N = 965.
# # Saving particle to disk. N = 966.
# # Saving particle to disk. N = 967.
# # Saving particle to disk. N = 968.
# # Saving particle to disk. N = 969.
# # Saving particle to disk. N = 970.
# # Saving particle to disk. N = 971.
# # Saving particle to disk. N = 972.
# # Saving particle to disk. N = 973.
# # Saving particle to disk. N = 974.
# # Saving particle to disk. N = 975.
# # Saving particle to disk. N = 976.
# # Saving particle to disk. N = 977.
# # Saving particle to disk. N = 978.
# # Saving particle to disk. N = 979.
# # Saving particle to disk. N = 980.
# # Saving particle to disk. N = 981.
# # Saving particle to disk. N = 982.
# # Saving particle to disk. N = 983.
# # Saving particle to disk. N = 984.
# # Saving particle to disk. N = 985.
# # Saving particle to disk. N = 986.
# # Saving particle to disk. N = 987.
# # Saving particle to disk. N = 988.
# # Saving particle to disk. N = 989.
# # Saving particle to disk. N = 990.
# # Saving particle to disk. N = 991.
# # Saving particle to disk. N = 992.
# # Creating level 17 with log likelihood = -2307.87846062.
# # Saving particle to disk. N = 993.
# # Saving particle to disk. N = 994.
# # Saving particle to disk. N = 995.
# # Saving particle to disk. N = 996.
# # Saving particle to disk. N = 997.
# # Saving particle to disk. N = 998.
# # Saving particle to disk. N = 999.
# # Saving particle to disk. N = 1000.
# # Saving particle to disk. N = 1001.
# # Saving particle to disk. N = 1002.
# # Saving particle to disk. N = 1003.
# # Saving particle to disk. N = 1004.
# # Saving particle to disk. N = 1005.
# # Saving particle to disk. N = 1006.
# # Saving particle to disk. N = 1007.
# # Saving particle to disk. N = 1008.
# # Saving particle to disk. N = 1009.
# # Saving particle to disk. N = 1010.
# # Saving particle to disk. N = 1011.
# # Saving particle to disk. N = 1012.
# # Saving particle to disk. N = 1013.
# # Saving particle to disk. N = 1014.
# # Saving particle to disk. N = 1015.
# # Saving particle to disk. N = 1016.
# # Saving particle to disk. N = 1017.
# # Saving particle to disk. N = 1018.
# # Saving particle to disk. N = 1019.
# # Saving particle to disk. N = 1020.
# # Saving particle to disk. N = 1021.
# # Saving particle to disk. N = 1022.
# # Saving particle to disk. N = 1023.
# # Saving particle to disk. N = 1024.
# # Saving particle to disk. N = 1025.
# # Saving particle to disk. N = 1026.
# # Saving particle to disk. N = 1027.
# # Saving particle to disk. N = 1028.
# # Saving particle to disk. N = 1029.
# # Saving particle to disk. N = 1030.
# # Saving particle to disk. N = 1031.
# # Saving particle to disk. N = 1032.
# # Saving particle to disk. N = 1033.
# # Saving particle to disk. N = 1034.
# # Saving particle to disk. N = 1035.
# # Saving particle to disk. N = 1036.
# # Saving particle to disk. N = 1037.
# # Saving particle to disk. N = 1038.
# # Saving particle to disk. N = 1039.
# # Saving particle to disk. N = 1040.
# # Saving particle to disk. N = 1041.
# # Saving particle to disk. N = 1042.
# # Saving particle to disk. N = 1043.
# # Saving particle to disk. N = 1044.
# # Saving particle to disk. N = 1045.
# # Saving particle to disk. N = 1046.
# # Saving particle to disk. N = 1047.
# # Saving particle to disk. N = 1048.
# # Saving particle to disk. N = 1049.
# # Saving particle to disk. N = 1050.
# # Saving particle to disk. N = 1051.
# # Saving particle to disk. N = 1052.
# # Saving particle to disk. N = 1053.
# # Saving particle to disk. N = 1054.
# # Saving particle to disk. N = 1055.
# # Saving particle to disk. N = 1056.
# # Saving particle to disk. N = 1057.
# # Saving particle to disk. N = 1058.
# # Saving particle to disk. N = 1059.
# # Saving particle to disk. N = 1060.
# # Saving particle to disk. N = 1061.
# # Saving particle to disk. N = 1062.
# # Saving particle to disk. N = 1063.
# # Saving particle to disk. N = 1064.
# # Saving particle to disk. N = 1065.
# # Saving particle to disk. N = 1066.
# # Saving particle to disk. N = 1067.
# # Saving particle to disk. N = 1068.
# # Saving particle to disk. N = 1069.
# # Saving particle to disk. N = 1070.
# # Saving particle to disk. N = 1071.
# # Saving particle to disk. N = 1072.
# # Saving particle to disk. N = 1073.
# # Saving particle to disk. N = 1074.
# # Saving particle to disk. N = 1075.
# # Saving particle to disk. N = 1076.
# # Saving particle to disk. N = 1077.
# # Saving particle to disk. N = 1078.
# # Saving particle to disk. N = 1079.
# # Saving particle to disk. N = 1080.
# # Saving particle to disk. N = 1081.
# # Saving particle to disk. N = 1082.
# # Saving particle to disk. N = 1083.
# # Creating level 18 with log likelihood = -2115.78285786.
# # Saving particle to disk. N = 1084.
# # Saving particle to disk. N = 1085.
# # Saving particle to disk. N = 1086.
# # Saving particle to disk. N = 1087.
# # Saving particle to disk. N = 1088.
# # Saving particle to disk. N = 1089.
# # Saving particle to disk. N = 1090.
# # Saving particle to disk. N = 1091.
# # Saving particle to disk. N = 1092.
# # Saving particle to disk. N = 1093.
# # Saving particle to disk. N = 1094.
# # Saving particle to disk. N = 1095.
# # Saving particle to disk. N = 1096.
# # Saving particle to disk. N = 1097.
# # Saving particle to disk. N = 1098.
# # Saving particle to disk. N = 1099.
# # Saving particle to disk. N = 1100.
# # Saving particle to disk. N = 1101.
# # Saving particle to disk. N = 1102.
# # Saving particle to disk. N = 1103.
# # Saving particle to disk. N = 1104.
# # Saving particle to disk. N = 1105.
# # Saving particle to disk. N = 1106.
# # Saving particle to disk. N = 1107.
# # Saving particle to disk. N = 1108.
# # Saving particle to disk. N = 1109.
# # Saving particle to disk. N = 1110.
# # Saving particle to disk. N = 1111.
# # Saving particle to disk. N = 1112.
# # Saving particle to disk. N = 1113.
# # Saving particle to disk. N = 1114.
# # Saving particle to disk. N = 1115.
# # Saving particle to disk. N = 1116.
# # Saving particle to disk. N = 1117.
# # Saving particle to disk. N = 1118.
# # Saving particle to disk. N = 1119.
# # Saving particle to disk. N = 1120.
# # Saving particle to disk. N = 1121.
# # Saving particle to disk. N = 1122.
# # Saving particle to disk. N = 1123.
# # Saving particle to disk. N = 1124.
# # Saving particle to disk. N = 1125.
# # Saving particle to disk. N = 1126.
# # Saving particle to disk. N = 1127.
# # Saving particle to disk. N = 1128.
# # Saving particle to disk. N = 1129.
# # Saving particle to disk. N = 1130.
# # Saving particle to disk. N = 1131.
# # Saving particle to disk. N = 1132.
# # Saving particle to disk. N = 1133.
# # Saving particle to disk. N = 1134.
# # Saving particle to disk. N = 1135.
# # Saving particle to disk. N = 1136.
# # Saving particle to disk. N = 1137.
# # Saving particle to disk. N = 1138.
# # Saving particle to disk. N = 1139.
# # Saving particle to disk. N = 1140.
# # Saving particle to disk. N = 1141.
# # Saving particle to disk. N = 1142.
# # Saving particle to disk. N = 1143.
# # Saving particle to disk. N = 1144.
# # Saving particle to disk. N = 1145.
# # Saving particle to disk. N = 1146.
# # Saving particle to disk. N = 1147.
# # Saving particle to disk. N = 1148.
# # Saving particle to disk. N = 1149.
# # Saving particle to disk. N = 1150.
# # Saving particle to disk. N = 1151.
# # Saving particle to disk. N = 1152.
# # Saving particle to disk. N = 1153.
# # Saving particle to disk. N = 1154.
# # Saving particle to disk. N = 1155.
# # Saving particle to disk. N = 1156.
# # Saving particle to disk. N = 1157.
# # Saving particle to disk. N = 1158.
# # Saving particle to disk. N = 1159.
# # Saving particle to disk. N = 1160.
# # Saving particle to disk. N = 1161.
# # Saving particle to disk. N = 1162.
# # Saving particle to disk. N = 1163.
# # Saving particle to disk. N = 1164.
# # Saving particle to disk. N = 1165.
# # Saving particle to disk. N = 1166.
# # Saving particle to disk. N = 1167.
# # Saving particle to disk. N = 1168.
# # Saving particle to disk. N = 1169.
# # Saving particle to disk. N = 1170.
# # Saving particle to disk. N = 1171.
# # Saving particle to disk. N = 1172.
# # Saving particle to disk. N = 1173.
# # Saving particle to disk. N = 1174.
# # Saving particle to disk. N = 1175.
# # Saving particle to disk. N = 1176.
# # Saving particle to disk. N = 1177.
# # Saving particle to disk. N = 1178.
# # Saving particle to disk. N = 1179.
# # Saving particle to disk. N = 1180.
# # Saving particle to disk. N = 1181.
# # Saving particle to disk. N = 1182.
# # Saving particle to disk. N = 1183.
# # Saving particle to disk. N = 1184.
# # Saving particle to disk. N = 1185.
# # Saving particle to disk. N = 1186.
# # Saving particle to disk. N = 1187.
# # Saving particle to disk. N = 1188.
# # Saving particle to disk. N = 1189.
# # Saving particle to disk. N = 1190.
# # Saving particle to disk. N = 1191.
# # Saving particle to disk. N = 1192.
# # Saving particle to disk. N = 1193.
# # Saving particle to disk. N = 1194.
# # Saving particle to disk. N = 1195.
# # Saving particle to disk. N = 1196.
# # Creating level 19 with log likelihood = -2009.05677306.
# # Saving particle to disk. N = 1197.
# # Saving particle to disk. N = 1198.
# # Saving particle to disk. N = 1199.
# # Saving particle to disk. N = 1200.
# # Saving particle to disk. N = 1201.
# # Saving particle to disk. N = 1202.
# # Saving particle to disk. N = 1203.
# # Saving particle to disk. N = 1204.
# # Saving particle to disk. N = 1205.
# # Saving particle to disk. N = 1206.
# # Saving particle to disk. N = 1207.
# # Saving particle to disk. N = 1208.
# # Saving particle to disk. N = 1209.
# # Saving particle to disk. N = 1210.
# # Saving particle to disk. N = 1211.
# # Saving particle to disk. N = 1212.
# # Saving particle to disk. N = 1213.
# # Saving particle to disk. N = 1214.
# # Saving particle to disk. N = 1215.
# # Saving particle to disk. N = 1216.
# # Saving particle to disk. N = 1217.
# # Saving particle to disk. N = 1218.
# # Saving particle to disk. N = 1219.
# # Saving particle to disk. N = 1220.
# # Saving particle to disk. N = 1221.
# # Saving particle to disk. N = 1222.
# # Saving particle to disk. N = 1223.
# # Saving particle to disk. N = 1224.
# # Saving particle to disk. N = 1225.
# # Saving particle to disk. N = 1226.
# # Saving particle to disk. N = 1227.
# # Saving particle to disk. N = 1228.
# # Saving particle to disk. N = 1229.
# # Saving particle to disk. N = 1230.
# # Saving particle to disk. N = 1231.
# # Saving particle to disk. N = 1232.
# # Saving particle to disk. N = 1233.
# # Saving particle to disk. N = 1234.
# # Saving particle to disk. N = 1235.
# # Saving particle to disk. N = 1236.
# # Saving particle to disk. N = 1237.
# # Saving particle to disk. N = 1238.
# # Saving particle to disk. N = 1239.
# # Saving particle to disk. N = 1240.
# # Saving particle to disk. N = 1241.
# # Saving particle to disk. N = 1242.
# # Saving particle to disk. N = 1243.
# # Saving particle to disk. N = 1244.
# # Saving particle to disk. N = 1245.
# # Saving particle to disk. N = 1246.
# # Saving particle to disk. N = 1247.
# # Saving particle to disk. N = 1248.
# # Saving particle to disk. N = 1249.
# # Saving particle to disk. N = 1250.
# # Saving particle to disk. N = 1251.
# # Saving particle to disk. N = 1252.
# # Saving particle to disk. N = 1253.
# # Saving particle to disk. N = 1254.
# # Saving particle to disk. N = 1255.
# # Saving particle to disk. N = 1256.
# # Saving particle to disk. N = 1257.
# # Saving particle to disk. N = 1258.
# # Saving particle to disk. N = 1259.
# # Saving particle to disk. N = 1260.
# # Saving particle to disk. N = 1261.
# # Saving particle to disk. N = 1262.
# # Saving particle to disk. N = 1263.
# # Saving particle to disk. N = 1264.
# # Saving particle to disk. N = 1265.
# # Saving particle to disk. N = 1266.
# # Saving particle to disk. N = 1267.
# # Saving particle to disk. N = 1268.
# # Saving particle to disk. N = 1269.
# # Saving particle to disk. N = 1270.
# # Saving particle to disk. N = 1271.
# # Saving particle to disk. N = 1272.
# # Saving particle to disk. N = 1273.
# # Saving particle to disk. N = 1274.
# # Saving particle to disk. N = 1275.
# # Saving particle to disk. N = 1276.
# # Saving particle to disk. N = 1277.
# # Saving particle to disk. N = 1278.
# # Saving particle to disk. N = 1279.
# # Saving particle to disk. N = 1280.
# # Saving particle to disk. N = 1281.
# # Saving particle to disk. N = 1282.
# # Saving particle to disk. N = 1283.
# # Saving particle to disk. N = 1284.
# # Saving particle to disk. N = 1285.
# # Saving particle to disk. N = 1286.
# # Saving particle to disk. N = 1287.
# # Saving particle to disk. N = 1288.
# # Saving particle to disk. N = 1289.
# # Saving particle to disk. N = 1290.
# # Saving particle to disk. N = 1291.
# # Saving particle to disk. N = 1292.
# ...
# # Saving particle to disk. N = 19580.
# # Saving particle to disk. N = 19581.
# # Saving particle to disk. N = 19582.
# # Saving particle to disk. N = 19583.
# # Saving particle to disk. N = 19584.
# # Saving particle to disk. N = 19585.
# # Saving particle to disk. N = 19586.
# # Saving particle to disk. N = 19587.
# # Saving particle to disk. N = 19588.
# # Saving particle to disk. N = 19589.
# # Saving particle to disk. N = 19590.
# # Saving particle to disk. N = 19591.
# # Saving particle to disk. N = 19592.
# # Saving particle to disk. N = 19593.
# # Saving particle to disk. N = 19594.
# # Saving particle to disk. N = 19595.
# # Saving particle to disk. N = 19596.
# # Saving particle to disk. N = 19597.
# # Saving particle to disk. N = 19598.
# # Saving particle to disk. N = 19599.
# # Saving particle to disk. N = 19600.
# # Saving particle to disk. N = 19601.
# # Saving particle to disk. N = 19602.
# # Saving particle to disk. N = 19603.
# # Saving particle to disk. N = 19604.
# # Saving particle to disk. N = 19605.
# # Saving particle to disk. N = 19606.
# # Saving particle to disk. N = 19607.
# # Saving particle to disk. N = 19608.
# # Saving particle to disk. N = 19609.
# # Saving particle to disk. N = 19610.
# # Saving particle to disk. N = 19611.
# # Saving particle to disk. N = 19612.
# # Saving particle to disk. N = 19613.
# # Saving particle to disk. N = 19614.
# # Saving particle to disk. N = 19615.
# # Saving particle to disk. N = 19616.
# # Saving particle to disk. N = 19617.
# # Saving particle to disk. N = 19618.
# # Saving particle to disk. N = 19619.
# # Saving particle to disk. N = 19620.
# # Saving particle to disk. N = 19621.
# # Saving particle to disk. N = 19622.
# # Saving particle to disk. N = 19623.
# # Saving particle to disk. N = 19624.
# # Saving particle to disk. N = 19625.
# # Saving particle to disk. N = 19626.
# # Saving particle to disk. N = 19627.
# # Saving particle to disk. N = 19628.
# # Saving particle to disk. N = 19629.
# # Saving particle to disk. N = 19630.
# # Saving particle to disk. N = 19631.
# # Saving particle to disk. N = 19632.
# # Saving particle to disk. N = 19633.
# # Saving particle to disk. N = 19634.
# # Saving particle to disk. N = 19635.
# # Saving particle to disk. N = 19636.
# # Saving particle to disk. N = 19637.
# # Saving particle to disk. N = 19638.
# # Saving particle to disk. N = 19639.
# # Saving particle to disk. N = 19640.
# # Saving particle to disk. N = 19641.
# # Saving particle to disk. N = 19642.
# # Saving particle to disk. N = 19643.
# # Saving particle to disk. N = 19644.
# # Saving particle to disk. N = 19645.
# # Saving particle to disk. N = 19646.
# # Saving particle to disk. N = 19647.
# # Saving particle to disk. N = 19648.
# # Saving particle to disk. N = 19649.
# # Saving particle to disk. N = 19650.
# # Saving particle to disk. N = 19651.
# # Saving particle to disk. N = 19652.
# # Saving particle to disk. N = 19653.
# # Saving particle to disk. N = 19654.
# # Saving particle to disk. N = 19655.
# # Saving particle to disk. N = 19656.
# # Saving particle to disk. N = 19657.
# # Saving particle to disk. N = 19658.
# # Saving particle to disk. N = 19659.
# # Saving particle to disk. N = 19660.
# # Saving particle to disk. N = 19661.
# # Saving particle to disk. N = 19662.
# # Saving particle to disk. N = 19663.
# # Saving particle to disk. N = 19664.
# # Saving particle to disk. N = 19665.
# # Saving particle to disk. N = 19666.
# # Saving particle to disk. N = 19667.
# # Saving particle to disk. N = 19668.
# # Saving particle to disk. N = 19669.
# # Saving particle to disk. N = 19670.
# # Saving particle to disk. N = 19671.
# # Saving particle to disk. N = 19672.
# # Saving particle to disk. N = 19673.
# # Saving particle to disk. N = 19674.
# # Saving particle to disk. N = 19675.
# # Saving particle to disk. N = 19676.
# # Saving particle to disk. N = 19677.
# # Saving particle to disk. N = 19678.
# # Saving particle to disk. N = 19679.
# # Saving particle to disk. N = 19680.
# # Saving particle to disk. N = 19681.
# # Saving particle to disk. N = 19682.
# # Saving particle to disk. N = 19683.
# # Saving particle to disk. N = 19684.
# # Saving particle to disk. N = 19685.
# # Saving particle to disk. N = 19686.
# # Saving particle to disk. N = 19687.
# # Saving particle to disk. N = 19688.
# # Saving particle to disk. N = 19689.
# # Saving particle to disk. N = 19690.
# # Saving particle to disk. N = 19691.
# # Saving particle to disk. N = 19692.
# # Saving particle to disk. N = 19693.
# # Saving particle to disk. N = 19694.
# # Saving particle to disk. N = 19695.
# # Saving particle to disk. N = 19696.
# # Saving particle to disk. N = 19697.
# # Saving particle to disk. N = 19698.
# # Saving particle to disk. N = 19699.
# # Saving particle to disk. N = 19700.
# # Saving particle to disk. N = 19701.
# # Saving particle to disk. N = 19702.
# # Saving particle to disk. N = 19703.
# # Saving particle to disk. N = 19704.
# # Saving particle to disk. N = 19705.
# # Saving particle to disk. N = 19706.
# # Saving particle to disk. N = 19707.
# # Saving particle to disk. N = 19708.
# # Saving particle to disk. N = 19709.
# # Saving particle to disk. N = 19710.
# # Saving particle to disk. N = 19711.
# # Saving particle to disk. N = 19712.
# # Saving particle to disk. N = 19713.
# # Saving particle to disk. N = 19714.
# # Saving particle to disk. N = 19715.
# # Saving particle to disk. N = 19716.
# # Saving particle to disk. N = 19717.
# # Saving particle to disk. N = 19718.
# # Saving particle to disk. N = 19719.
# # Saving particle to disk. N = 19720.
# # Saving particle to disk. N = 19721.
# # Saving particle to disk. N = 19722.
# # Saving particle to disk. N = 19723.
# # Saving particle to disk. N = 19724.
# # Saving particle to disk. N = 19725.
# # Saving particle to disk. N = 19726.
# # Saving particle to disk. N = 19727.
# # Saving particle to disk. N = 19728.
# # Saving particle to disk. N = 19729.
# # Saving particle to disk. N = 19730.
# # Saving particle to disk. N = 19731.
# # Saving particle to disk. N = 19732.
# # Saving particle to disk. N = 19733.
# # Saving particle to disk. N = 19734.
# # Saving particle to disk. N = 19735.
# # Saving particle to disk. N = 19736.
# # Saving particle to disk. N = 19737.
# # Saving particle to disk. N = 19738.
# # Saving particle to disk. N = 19739.
# # Saving particle to disk. N = 19740.
# # Saving particle to disk. N = 19741.
# # Saving particle to disk. N = 19742.
# # Saving particle to disk. N = 19743.
# # Saving particle to disk. N = 19744.
# # Saving particle to disk. N = 19745.
# # Saving particle to disk. N = 19746.
# # Saving particle to disk. N = 19747.
# # Saving particle to disk. N = 19748.
# # Saving particle to disk. N = 19749.
# # Saving particle to disk. N = 19750.
# # Saving particle to disk. N = 19751.
# # Saving particle to disk. N = 19752.
# # Saving particle to disk. N = 19753.
# # Saving particle to disk. N = 19754.
# # Saving particle to disk. N = 19755.
# # Saving particle to disk. N = 19756.
# # Saving particle to disk. N = 19757.
# # Saving particle to disk. N = 19758.
# # Saving particle to disk. N = 19759.
# # Saving particle to disk. N = 19760.
# # Saving particle to disk. N = 19761.
# # Saving particle to disk. N = 19762.
# # Saving particle to disk. N = 19763.
# # Saving particle to disk. N = 19764.
# # Saving particle to disk. N = 19765.
# # Saving particle to disk. N = 19766.
# # Saving particle to disk. N = 19767.
# # Saving particle to disk. N = 19768.
# # Saving particle to disk. N = 19769.
# # Saving particle to disk. N = 19770.
# # Saving particle to disk. N = 19771.
# # Saving particle to disk. N = 19772.
# # Saving particle to disk. N = 19773.
# # Saving particle to disk. N = 19774.
# # Saving particle to disk. N = 19775.
# # Saving particle to disk. N = 19776.
# # Saving particle to disk. N = 19777.
# # Saving particle to disk. N = 19778.
# # Saving particle to disk. N = 19779.
# # Saving particle to disk. N = 19780.
# # Saving particle to disk. N = 19781.
# # Saving particle to disk. N = 19782.
# # Saving particle to disk. N = 19783.
# # Saving particle to disk. N = 19784.
# # Saving particle to disk. N = 19785.
# # Saving particle to disk. N = 19786.
# # Saving particle to disk. N = 19787.
# # Saving particle to disk. N = 19788.
# # Saving particle to disk. N = 19789.
# # Saving particle to disk. N = 19790.
# # Saving particle to disk. N = 19791.
# # Saving particle to disk. N = 19792.
# # Saving particle to disk. N = 19793.
# # Saving particle to disk. N = 19794.
# # Saving particle to disk. N = 19795.
# # Saving particle to disk. N = 19796.
# # Saving particle to disk. N = 19797.
# # Saving particle to disk. N = 19798.
# # Saving particle to disk. N = 19799.
# # Saving particle to disk. N = 19800.
# # Saving particle to disk. N = 19801.
# # Saving particle to disk. N = 19802.
# # Saving particle to disk. N = 19803.
# # Saving particle to disk. N = 19804.
# # Saving particle to disk. N = 19805.
# # Saving particle to disk. N = 19806.
# # Saving particle to disk. N = 19807.
# # Saving particle to disk. N = 19808.
# # Saving particle to disk. N = 19809.
# # Saving particle to disk. N = 19810.
# # Saving particle to disk. N = 19811.
# # Saving particle to disk. N = 19812.
# # Saving particle to disk. N = 19813.
# # Saving particle to disk. N = 19814.
# # Saving particle to disk. N = 19815.
# # Saving particle to disk. N = 19816.
# # Saving particle to disk. N = 19817.
# # Saving particle to disk. N = 19818.
# # Saving particle to disk. N = 19819.
# # Saving particle to disk. N = 19820.
# # Saving particle to disk. N = 19821.
# # Saving particle to disk. N = 19822.
# # Saving particle to disk. N = 19823.
# # Saving particle to disk. N = 19824.
# # Saving particle to disk. N = 19825.
# # Saving particle to disk. N = 19826.
# # Saving particle to disk. N = 19827.
# # Saving particle to disk. N = 19828.
# # Saving particle to disk. N = 19829.
# # Saving particle to disk. N = 19830.
# # Saving particle to disk. N = 19831.
# # Saving particle to disk. N = 19832.
# # Saving particle to disk. N = 19833.
# # Saving particle to disk. N = 19834.
# # Saving particle to disk. N = 19835.
# # Saving particle to disk. N = 19836.
# # Saving particle to disk. N = 19837.
# # Saving particle to disk. N = 19838.
# # Saving particle to disk. N = 19839.
# # Saving particle to disk. N = 19840.
# # Saving particle to disk. N = 19841.
# # Saving particle to disk. N = 19842.
# # Saving particle to disk. N = 19843.
# # Saving particle to disk. N = 19844.
# # Saving particle to disk. N = 19845.
# # Saving particle to disk. N = 19846.
# # Saving particle to disk. N = 19847.
# # Saving particle to disk. N = 19848.
# # Saving particle to disk. N = 19849.
# # Saving particle to disk. N = 19850.
# # Saving particle to disk. N = 19851.
# # Saving particle to disk. N = 19852.
# # Saving particle to disk. N = 19853.
# # Saving particle to disk. N = 19854.
# # Saving particle to disk. N = 19855.
# # Saving particle to disk. N = 19856.
# # Saving particle to disk. N = 19857.
# # Saving particle to disk. N = 19858.
# # Saving particle to disk. N = 19859.
# # Saving particle to disk. N = 19860.
# # Saving particle to disk. N = 19861.
# # Saving particle to disk. N = 19862.
# # Saving particle to disk. N = 19863.
# # Saving particle to disk. N = 19864.
# # Saving particle to disk. N = 19865.
# # Saving particle to disk. N = 19866.
# # Saving particle to disk. N = 19867.
# # Saving particle to disk. N = 19868.
# # Saving particle to disk. N = 19869.
# # Saving particle to disk. N = 19870.
# # Saving particle to disk. N = 19871.
# # Saving particle to disk. N = 19872.
# # Saving particle to disk. N = 19873.
# # Saving particle to disk. N = 19874.
# # Saving particle to disk. N = 19875.
# # Saving particle to disk. N = 19876.
# # Saving particle to disk. N = 19877.
# # Saving particle to disk. N = 19878.
# # Saving particle to disk. N = 19879.
# # Saving particle to disk. N = 19880.
# # Saving particle to disk. N = 19881.
# # Saving particle to disk. N = 19882.
# # Saving particle to disk. N = 19883.
# # Saving particle to disk. N = 19884.
# # Saving particle to disk. N = 19885.
# # Saving particle to disk. N = 19886.
# # Saving particle to disk. N = 19887.
# # Saving particle to disk. N = 19888.
# # Saving particle to disk. N = 19889.
# # Saving particle to disk. N = 19890.
# # Saving particle to disk. N = 19891.
# # Saving particle to disk. N = 19892.
# # Saving particle to disk. N = 19893.
# # Saving particle to disk. N = 19894.
# # Saving particle to disk. N = 19895.
# # Saving particle to disk. N = 19896.
# # Saving particle to disk. N = 19897.
# # Saving particle to disk. N = 19898.
# # Saving particle to disk. N = 19899.
# # Saving particle to disk. N = 19900.
# # Saving particle to disk. N = 19901.
# # Saving particle to disk. N = 19902.
# # Saving particle to disk. N = 19903.
# # Saving particle to disk. N = 19904.
# # Saving particle to disk. N = 19905.
# # Saving particle to disk. N = 19906.
# # Saving particle to disk. N = 19907.
# # Saving particle to disk. N = 19908.
# # Saving particle to disk. N = 19909.
# # Saving particle to disk. N = 19910.
# # Saving particle to disk. N = 19911.
# # Saving particle to disk. N = 19912.
# # Saving particle to disk. N = 19913.
# # Saving particle to disk. N = 19914.
# # Saving particle to disk. N = 19915.
# # Saving particle to disk. N = 19916.
# # Saving particle to disk. N = 19917.
# # Saving particle to disk. N = 19918.
# # Saving particle to disk. N = 19919.
# # Saving particle to disk. N = 19920.
# # Saving particle to disk. N = 19921.
# # Saving particle to disk. N = 19922.
# # Saving particle to disk. N = 19923.
# # Saving particle to disk. N = 19924.
# # Saving particle to disk. N = 19925.
# # Saving particle to disk. N = 19926.
# # Saving particle to disk. N = 19927.
# # Saving particle to disk. N = 19928.
# # Saving particle to disk. N = 19929.
# # Saving particle to disk. N = 19930.
# # Saving particle to disk. N = 19931.
# # Saving particle to disk. N = 19932.
# # Saving particle to disk. N = 19933.
# # Saving particle to disk. N = 19934.
# # Saving particle to disk. N = 19935.
# # Saving particle to disk. N = 19936.
# # Saving particle to disk. N = 19937.
# # Saving particle to disk. N = 19938.
# # Saving particle to disk. N = 19939.
# # Saving particle to disk. N = 19940.
# # Saving particle to disk. N = 19941.
# # Saving particle to disk. N = 19942.
# # Saving particle to disk. N = 19943.
# # Saving particle to disk. N = 19944.
# # Saving particle to disk. N = 19945.
# # Saving particle to disk. N = 19946.
# # Saving particle to disk. N = 19947.
# # Saving particle to disk. N = 19948.
# # Saving particle to disk. N = 19949.
# # Saving particle to disk. N = 19950.
# # Saving particle to disk. N = 19951.
# # Saving particle to disk. N = 19952.
# # Saving particle to disk. N = 19953.
# # Saving particle to disk. N = 19954.
# # Saving particle to disk. N = 19955.
# # Saving particle to disk. N = 19956.
# # Saving particle to disk. N = 19957.
# # Saving particle to disk. N = 19958.
# # Saving particle to disk. N = 19959.
# # Saving particle to disk. N = 19960.
# # Saving particle to disk. N = 19961.
# # Saving particle to disk. N = 19962.
# # Saving particle to disk. N = 19963.
# # Saving particle to disk. N = 19964.
# # Saving particle to disk. N = 19965.
# # Saving particle to disk. N = 19966.
# # Saving particle to disk. N = 19967.
# # Saving particle to disk. N = 19968.
# # Saving particle to disk. N = 19969.
# # Saving particle to disk. N = 19970.
# # Saving particle to disk. N = 19971.
# # Saving particle to disk. N = 19972.
# # Saving particle to disk. N = 19973.
# # Saving particle to disk. N = 19974.
# # Saving particle to disk. N = 19975.
# # Saving particle to disk. N = 19976.
# # Saving particle to disk. N = 19977.
# # Saving particle to disk. N = 19978.
# # Saving particle to disk. N = 19979.
# # Saving particle to disk. N = 19980.
# # Saving particle to disk. N = 19981.
# # Saving particle to disk. N = 19982.
# # Saving particle to disk. N = 19983.
# # Saving particle to disk. N = 19984.
# # Saving particle to disk. N = 19985.
# # Saving particle to disk. N = 19986.
# # Saving particle to disk. N = 19987.
# # Saving particle to disk. N = 19988.
# # Saving particle to disk. N = 19989.
# # Saving particle to disk. N = 19990.
# # Saving particle to disk. N = 19991.
# # Saving particle to disk. N = 19992.
# # Saving particle to disk. N = 19993.
# # Saving particle to disk. N = 19994.
# # Saving particle to disk. N = 19995.
# # Saving particle to disk. N = 19996.
# # Saving particle to disk. N = 19997.
# # Saving particle to disk. N = 19998.
# # Saving particle to disk. N = 19999.
# # Saving particle to disk. N = 20000.

# %%
# Run postprocessing
# !python showresults.py
# Out:
# log(Z) = -1807.65958462
# Information = 28.4445808527 nats.
# Effective sample size = 3575.23074615
# <matplotlib.figure.Figure at 0x153d8100d518>
# <matplotlib.figure.Figure at 0x153d7557c048>
# <matplotlib.figure.Figure at 0x153d69e0d630>
# <matplotlib.figure.Figure at 0x153d69a23080>

# %%
# Load the posterior samples
posterior_samples = np.loadtxt('posterior_sample.txt')

print(posterior_samples.shape)
# Out:
# (3575, 6)

# %%
# %cd ../NS_model
# Out:
# /home/fran/drive/projects/PSPL_model/NS_model

# %%
import corner 
from IPython.display import display, Math

lbls = [r'$\Delta F$', r'$F_b$', r'$t_0$', r'$u_0$', r'$t_E$', r'$\rho_s$']
labels = [r'\Delta F', r'F_b', r't_0', r'u_0', r't_E', r'\rho_s']

ndim = 6

for i in range(ndim):
    mcmc = np.percentile(posterior_samples[:, i], [5, 50, 95])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
    
fig = corner.corner(posterior_samples, labels=lbls)
# Out:
# $$\mathrm{\Delta F} = 1.878_{-0.063}^{0.064}$$
# $$\mathrm{F_b} = 2.185_{-0.004}^{0.004}$$
# $$\mathrm{t_0} = 7843.580_{-0.173}^{0.170}$$
# $$\mathrm{u_0} = 0.596_{-0.212}^{0.399}$$
# $$\mathrm{t_E} = 10.324_{-2.888}^{3.379}$$
# $$\mathrm{\rho_s} = 0.000_{-0.000}^{0.202}$$

# %%
def pspl_flux(t, pars):
        """
        Evaluate a PSPL model at the input t values.


        Parameters
        ----------
        pars : list, array
            This should be a length-5 array or list containing the 
            parameter values (DeltaF, Fb, t0, u0, tE).
        t : numeric, list, array
            The time values.

        Returns
        -------
        F : array
            The computed flux values at each input t.
        """
            
        DeltaF, Fb, t0, u0, tE = pars

        u = np.sqrt(u0**2 + ((t - t0)/tE)**2)
        A = lambda u: (u**2 + 2)/(u*np.sqrt(u**2 + 4))

        return DeltaF*(A(u) - 1)/(A(u0) - 1) + Fb    

def plot_data(ax, t, F, sigF):
    ax.errorbar(t, F, sigF, fmt='.', color='black')
    ax.grid(True)
    ax.set_xlabel('$(t-\overline{t_0})$ [days]')
    ax.set_ylabel('$(F-\overline{F_b})/\overline{\Delta F}$')
    ax.set_title('OGLE-2017-BLG-0401');
    

def plot_model_and_data(ax, t, F, sigF, posterior):
    t0_median = np.percentile(posterior[:, 2], [50])[0]
    Fb_median = np.percentile(posterior[:, 1], [50])[0]
    DeltaF_median = np.percentile(posterior[:, 0], [50])[0]

    x = t - t0_median
    y = (F - Fb_median)/DeltaF_median

    # Plot data
    plot_data(ax, x, y, sigF/DeltaF_median)

    # Plot model in data space
    x_ = np.linspace(t[0], t[-1], 2000) 

    for pars in posterior[:128]: # only plot 128 samples
        y_ = (pspl_flux(x_, pars) - Fb_median)/DeltaF_median
        ax.plot(x_ - t0_median, y_,
                 marker='', linestyle='-', color='#3182bd', alpha=0.1, zorder=-10)

    ax.set_xlim(-100,100)
    
fig, ax = plt.subplots(figsize=(16,8))
plot_model_and_data(ax, data['HJD'].values, data['I_flux'].values, 
                    data['I_flux_err'].values, posterior_samples)
